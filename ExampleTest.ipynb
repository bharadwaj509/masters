# %%
from textblob.classifiers import PositiveNaiveBayesClassifier
sports_sentences = ['The team dominated the game',
                        'They lost the ball',
                        'The game was intense',
                        'The goalkeeper catched the ball',
                        'The other team controlled the ball',
                        'The President did not comment',
                         'I lost the keys',
                         'The team won the game',
                         'Sara has two kids',
                         'The ball went off the court',
                         'They had the ball for the whole game',
                         'The show is over']

various_sentences = ['The President did not comment',
                         'I lost the keys',
                         'The team won the game',
                         'Sara has two kids',
                         'The ball went off the court',
                         'They had the ball for the whole game',
                         'The show is over']
classifier = PositiveNaiveBayesClassifier(positive_set=sports_sentences,
                                unlabeled_set=various_sentences)

# %%
classifier.classify("My team lost the game")
# Out:
# True

# %%
classifier.classify("I am having lunch")
# Out:
# False

# %%
import numpy as np
X = 0.3 * np.random.randn(100, 2)
X_train = np.r_[X + 2, X - 2]
X_train
# Out:
# array([[ 1.86069563,  2.43628134],
#        [ 2.06511393,  2.04430711],
#        [ 1.76729765,  2.00081521],
#        [ 2.22058749,  2.02956334],
#        [ 1.77476419,  2.7836564 ],
#        [ 2.10034787,  2.95198459],
#        [ 1.92155594,  2.09398045],
#        [ 1.88425798,  2.26662249],
#        [ 1.59017681,  2.48709121],
#        [ 1.77934057,  2.05647254],
#        [ 1.98652354,  1.87154148],
#        [ 2.05872118,  2.05846103],
#        [ 1.34406298,  2.1331689 ],
#        [ 1.76904684,  2.47971357],
#        [ 2.84039928,  2.56460921],
#        [ 2.62611075,  1.46251064],
#        [ 1.95398872,  1.84422635],
#        [ 1.88680639,  2.20118811],
#        [ 1.82935607,  1.42526888],
#        [ 1.64516796,  1.47527806],
#        [ 1.93069431,  2.17633032],
#        [ 2.10451422,  2.24061594],
#        [ 2.06546907,  2.29106247],
#        [ 2.03755201,  1.77730295],
#        [ 2.5755905 ,  1.81220666],
#        [ 2.17264074,  1.8799633 ],
#        [ 1.78177152,  1.61846618],
# ...

# %%
X[0]
# Out:
# array([-0.13930437,  0.43628134])

# %%
# svm one-class
from sklearn import svm
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
# clf = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
# clf.fit(sports_sentences)
targets = [1,1,1,1,1]
text_clf = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('clf', svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1))])

_ = text_clf.fit(sports_sentences, targets)

# %%
result = text_clf.predict(sports_sentences)
for i in range(len(sports_sentences)):
    print sports_sentences[i],result[i]
# Out:
# The team dominated the game 1.0
# They lost the ball 1.0
# The game was intense 1.0
# The goalkeeper catched the ball 1.0
# The other team controlled the ball -1.0
# The President did not comment 1.0
# I lost the keys 1.0
# The team won the game 1.0
# Sara has two kids -1.0
# The ball went off the court 1.0
# They had the ball for the whole game -1.0
# The show is over -1.0
